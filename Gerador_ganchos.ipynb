# %%
# @title Instalação do wrapper da API do Gemini {display-mode: "form"}
# !pip install -q -U google-generativeai

# %% [markdown]
# #### Configurando a chave da API

# %%
# @title Insira a chave da API {display-mode: "form"}
import google.generativeai as genai
from IPython.display import display, Markdown

GOOGLE_API_KEY="" # @param {type: "string"}
genai.configure(api_key=GOOGLE_API_KEY)

# %%
# @title ### Configuração e escolha do modelo {display-mode: "form"}
generation_config = {
  "temperature": 0.9555,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 16384
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_ONLY_HIGH"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_ONLY_HIGH"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_NONE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_NONE"
  },
]
modelo = "gemini-1.0-pro" # @param ["gemini-1.0-pro", "gemini-1.5-pro-latest"]
instruction = "Você é um ajudante de um mestre de RPG. Você vai ajudar na criação de ganchos, personagens e descrições. O sistema de RPG é o Tormenta20, no cenário padrão de Arton. Considere por padrão, caso não seja informado, um grupo de 4 aventureiros de nível 1. Seja descritivo no gancho especialmente no ambiente. As descrições devem auxiliar o mestre. Gere descrições detalhadas dos ambientes. O gancho deve vir primeiro, seguido das descrições dos NPCs. Formate a saída utilizando markdown. Gere descrições detalhadas para os NPCs."

model = genai.GenerativeModel(model_name=modelo,
                              generation_config=generation_config,
                              safety_settings=safety_settings)

prompt_parts = [
  instruction,
  "input: Uma prisão onde os aventureiros devem escapar.",
  "output: # Prisão de Altzada\n\n## Gancho\n\nOs aventureiros se veem presos na infame Prisão de Altzada, localizada em uma ilha remota na costa oeste de Trebuck. A prisão é conhecida por sua segurança impenetrável, com guardas corruptos e cruéis e uma história de aprisionamento de alguns dos criminosos mais perigosos de Arton. Os aventureiros foram presos injustamente, vítimas de uma conspiração orquestrada por um nobre poderoso que buscava silenciá-los após descobrirem um segredo comprometedor. A única esperança dos aventureiros é escapar da prisão, limpando seus nomes e expondo a verdade por trás de sua prisão.\n\n## Descrição da Prisão de Altzada\n\nA Prisão de Altzada é uma fortaleza de pedra sombria, erguida sobre um afloramento rochoso que se projeta para o mar revolto. Paredes altas e torres de vigia imponentes dominam a paisagem, transmitindo uma sensação de isolamento e desespero. O mar bate contra as paredes da prisão, criando um rugido constante que ecoa pelos corredores úmidos e frios.\n\n### Pátio\n\nO pátio da prisão é uma área aberta e desolada, cercada por muros altos. Pedras irregulares e rachadas formam o chão, e alguns tufos de grama resistente lutam para sobreviver sob a sombra constante dos muros. Um poço no centro fornece água potável, mas é frequentemente contaminada por detritos. Guardas patrulham o pátio dia e noite, seus olhos atentos a qualquer sinal de problema.\n\n### Bloco de Celas\n\nO bloco de celas é um labirinto de corredores estreitos e úmidos. As celas são pequenas e apertadas, com paredes de pedra fria e grades enferrujadas. Uma única tocha bruxuleante ilumina fracamente o corredor, lançando sombras longas e sinistras. O ar é denso com o cheiro de suor, mofo e medo.\n\n### Refeitório\n\nO refeitório é uma sala grande e cavernosa com mesas e bancos de madeira toscamente construídos. As refeições são escassas e intragáveis, geralmente compostas por um ensopado ralo e pão duro. Brigas e disputas são comuns, pois os prisioneiros competem por cada migalha de comida.\n\n### Masmorras\n\nAs masmorras ficam abaixo do bloco de celas, em um nível ainda mais escuro e úmido. As celas aqui são ainda menores e mais isoladas, reservadas para os prisioneiros mais perigosos e indisciplinados. Correntes enferrujadas pendem das paredes, e instrumentos de tortura estão espalhados pelos cantos.\n\n### Escritório do Alcaide\n\nO escritório do Alcaide é uma sala luxuosa em comparação com o resto da prisão. Uma lareira crepita alegremente, tapetes felpudos cobrem o chão, e uma grande mesa de carvalho domina a sala. O Alcaide, um homem corpulento e cruel chamado Gorion, governa a prisão com mão de ferro, usando tortura e intimidação para manter os prisioneiros sob controle.\n\n## NPCs\n\n**Gorion, o Alcaide:**\n\n* **Descrição:** Um homem corpulento e imponente, com um rosto vermelho e inchado e um olhar frio e calculador. Ele está sempre vestido com um uniforme impecável, com uma pesada corrente de ouro pendurada no pescoço.\n* **Personalidade:** Cruel, ganancioso e corrupto. Ele se deleita em infligir dor e sofrimento aos prisioneiros, e está sempre disposto a aceitar subornos.\n* **Motivações:** Manter o controle da prisão e acumular riqueza.\n* **Segredos:** Está envolvido em um esquema de contrabando com um grupo de piratas, usando a prisão como base de operações.\n\n**Brutus, o Carcereiro-Chefe:**\n\n* **Descrição:** Um homem forte e brutal com um rosto marcado por cicatrizes. Ele carrega um chicote pesado e um molho de chaves enferrujadas na cintura.\n* **Personalidade:** Sádico, cruel e desprovido de qualquer senso de compaixão. Ele gosta de torturar prisioneiros e obedece cegamente às ordens de Gorion.\n* **Motivações:** Impor sua autoridade sobre os prisioneiros e ganhar o favor de Gorion.\n* **Segredos:** Nutre um ódio profundo por um dos prisioneiros, um antigo rival de seu passado.\n\n**Cassia, a Curandeira:**\n\n* **Descrição:** Uma mulher de meia-idade com um rosto cansado e gentil. Ela usa um vestido simples e carrega uma bolsa de couro cheia de ervas e unguentos.\n* **Personalidade:** Bondosa, compassiva e preocupada com o bem-estar dos prisioneiros. Ela faz o possível para aliviar seu sofrimento, apesar dos recursos limitados.\n* **Motivações:** Ajudar os necessitados e encontrar redenção por erros do passado.\n* **Segredos:** Já foi uma aventureira renomada, mas foi forçada a abandonar sua antiga vida após uma tragédia.\n\n**Darius, o Prisioneiro Misterioso:**\n\n* **Descrição:** Um homem encapuzado envolto em sombras, com uma aura de mistério e perigo. Ele permanece em silêncio na maior parte do tempo, observando tudo com seus olhos penetrantes.\n* **Personalidade:** Calado, reservado e enigmático. Seus motivos são desconhecidos, mas ele parece possuir um conhecimento profundo da prisão e seus segredos.\n* **Motivações:** Desconhecidas.\n* **Segredos:** Possui habilidades mágicas latentes e sabe mais sobre a conspiração que levou à prisão dos aventureiros do que deixa transparecer.\n\nCom a ajuda desses elementos, o mestre terá ferramentas para criar uma aventura emocionante e cheia de suspense, levando os aventureiros a desvendar os segredos da Prisão de Altzada e lutar pela sua liberdade.",
  "input: Uma vila onde todos os aventureiros do grupo moram sendo atacada por monstros insetóides.",
comum de transporte, utilizada para levar passageiros e cargas através das vastas planícies de Arton.  \n\n**Detalhes:**\n\n* **Estrutura:** Construída em madeira resistente, com eixos reforçados e rodas de ferro.\n* **Compartimento de passageiros:** Coberto por uma lona esfarrapada, oferecendo pouca proteção contra sol e chuva. Assentos de madeira bruta, sem qualquer tipo de estofamento, tornavam a viagem desconfortável.\n* **Compartimento de carga:** Um espaço aberto na parte traseira da carroça, utilizado para transportar mercadorias e bagagem.\n\n## Descrição da Cidade Tartaruga\n\nUma criatura colossal de proporções épicas.\n\n**Detalhes:**\n\n* **Tamanho:** Gigantesca, com quilômetros de comprimento e largura.\n* **Carapaça:** Coberta por uma espessa camada de terra, vegetação e rochas, formando uma paisagem complexa. \n* **Cidade:**  Construída sobre a carapaça da tartaruga, com edifícios de diferentes estilos arquitetônicos, campos cultivados, estradas e pontes.\n* **Movimento:** Lento e constante, provocando tremores de terra a cada passo.\n\n## NPCs:\n\n**Grog, o Cocheiro:**\n\n* **Descrição:** Um homem de meia-idade, magro e musculoso, com o rosto curtido pelo sol e as mãos calejadas. Vestia roupas simples de viagem e um chapéu de abas largas.\n* **Personalidade:**  Calado, taciturno e desconfiado. Conhecia as estradas como a palma da sua mão, mas preferia a companhia dos seus cavalos à de outras pessoas.\n* **Motivações:**  Completar a viagem em segurança e receber o seu pagamento.\n\n**Ayla, a Mercadora:**\n\n* **Descrição:** Uma mulher robusta de meia-idade, com cabelos ruivos presos em um coque apertado e olhos azuis astutos. Vestia roupas de viagem de boa qualidade e carregava consigo um baú cheio de mercadorias exóticas.\n* **Personalidade:**  Perspicaz, negociadora habilidosa e com uma língua afiada. Adorava uma boa conversa e sempre buscava oportunidades de lucro.\n* **Motivações:**  Vender suas mercadorias com o maior lucro possível e explorar novas oportunidades de negócio.\n\n**Theron, o Acólito:**\n\n* **Descrição:** Um jovem magro e pálido, com cabelos castanhos curtos e olhos escuros e intensos. Vestia uma túnica simples e carregava consigo um cajado de madeira e um livro sagrado.\n* **Personalidade:**  Devoto, estudioso e um pouco ingênuo. Acreditava na bondade inerente das pessoas e buscava sempre ajudar os necessitados.\n* **Motivações:**  Compreender o mundo através dos ensinamentos divinos e levar conforto espiritual aos que sofrem.",
  "input: Uma feira de comércio acontece na cidade de Ridembarr.",
  "output: # A Feira de Maravilhas de Ridembarr\n\n**Gancho:**\n\nAs ruas de Ridembarr, normalmente movimentadas com o burburinho do comércio cotidiano, estão ainda mais vibrantes e caóticas do que o usual. Bandeirolas multicoloridas esvoaçam ao vento, música animada ecoa por entre as barracas ricamente decoradas e o aroma delicioso de comidas exóticas invade as narinas dos visitantes. É época da Feira de Maravilhas, um evento anual que atrai mercadores, artistas e curiosos de todos os cantos de Arton e além. \n\nOs aventureiros, movidos por diferentes razões, se veem em meio a este turbilhão de cores, sons e aromas. Talvez estejam em busca de itens raros e poderosos para auxiliar em suas missões, ou apenas desejam se divertir e experimentar as maravilhas que a feira tem a oferecer.  As possibilidades são infinitas: encontrar um artefato mágico peculiar, se envolver em uma disputa acirrada em um jogo de azar, testemunhar uma performance
** Um homem alto e imponente, com rosto marcado e olhar severo. Ele veste a armadura completa da guarda de Ridembarr e carrega uma espada longa na cintura.\n* **Personalidade:**  Justo, incorruptível e dedicado à segurança de Ridembarr.  Ele não tolera crimes, especialmente durante a feira, e está determinado a prender um  criminoso procurado.\n* **Motivações:** Manter a ordem na cidade e capturar o fugitivo a todo custo.\n* **Segredos:**  Alaric esconde uma grande tristeza pela perda de sua esposa, assassinada pelo  criminoso que ele busca capturar.\n\nCom este gancho detalhado e descrições completas de personagens e locais, o Mestre terá uma base sólida para construir uma aventura emocionante e cheia de surpresas, levando os aventureiros a explorar as maravilhas e os perigos da Feira de Ridembarr e descobrir os segredos que se escondem sob a superfície vibrante do evento.",
]

# %% [markdown]
# # Criador de Ganchos para Aventuras!
#
# ## 💭 Motivação
#
# Decidi criar este projeto devido a uma necessidade própria: costumo mestrar diversas aventuras *one-shot* para grupos iniciantes, e a parte de iniciar uma aventura geralmente requer planejamento prévio, especialmente na construção de cenários, personagens, etc. A capacidade generativa do Gemini foi uma das características mais atrativas para ajudar na geração de conteúdo, auxiliando na descrição de ambientes e personagens. Em outras palavras, me ajudaria a economizar tempo de planejamento, pelo menos para *one-shots* e inícios de aventuras 😅.
#
# ## ❗ Como funciona
#
# Utilizei a abordagem de *few-shot prompting*, incluindo exemplos no início de cada prompt para ditar a estrutura geral do markdown. Alguns exemplos foram gerados previamente com o próprio Gemini. Inicialmente, usava o `gemini-1.5-pro-latest`, mas acredito que o usei demais em outros projetos e recebi muitos *timeouts*. Mudei para o `gemini-1.0` e, apesar de fornecer descrições menos longas que o `1.5-pro-latest`, especialmente em características e detalhes, ele tem um desempenho razoável para o projeto. Para testar, basta mudar o modelo utilizado.
#
# ## 📑 Como usar
#
# Simplesmente escreva alguma ideia inicial para a aventura/gancho. Alternativamente, deixar o campo `ideia` em branco fará o modelo gerar um gancho aleatório, às vezes sem um título. O modelo foi instruído para gerar uma saída formatada em `markdown`, conforme os exemplos, facilitando a leitura.

# %%
# @title #### Entre com uma ideia inicial para a aventura... {display-mode: "form"}
ideia = "Um grupo de aventureiros acordam sem se lembrar de nada em uma prisão situada na encosta de um penhasco." # @param  {type:"string"}

user_text = "input: " + ideia

prompt_parts.append(user_text)
prompt_parts.append("output: ")

response = model.generate_content(prompt_parts)
display(Markdown(response.text))
# Out:
# ## Gancho: Memória Perdida
#
# Os aventureiros despertam em celas escuras e frias, suas mentes confusas e vazias. Eles não têm nenhuma lembrança de quem são, como chegaram lá ou por que estão presos. A única coisa que veem é uma pequena janela com grades, oferecendo uma vista de um penhasco íngreme e do oceano tempestuoso abaixo.
#
# O ar é pesado com umidade e o cheiro de salitre. Os aventureiros estão vestindo roupas ásperas de prisão, e suas mãos e pés estão acorrentados. Eles tentam se lembrar, mas tudo o que encontram é um vazio inquietante.
#
# Enquanto se sentam em suas celas, tentando desesperadamente recuperar suas memórias, eles ouvem passos se aproximando. Uma porta de metal enferrujada se abre e um guarda entra, seu rosto uma máscara de crueldade.
#
# "Hora do trabalho", rosna ele. "Sigam-me."
#
# ...
